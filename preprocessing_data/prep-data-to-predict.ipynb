# %%
# !pip install pyEDFlib

# %%
import numpy as np
from pyedflib import highlevel
import matplotlib.pyplot as plt
import torch
import torch.nn
from scipy.signal import welch
import pandas as pd

# %%
sample_rate = 400

# %%
file = "/kaggle/input/kriski/data/ECoG_fully_marked_4 2 files 6 h each/Ati4x3_12m_BL_6h_fully_marked.edf"

# %%
signals, _, header = highlevel.read_edf(file1)
time = np.arange(signals1.shape[1]) / sample_rate

df = pd.DataFrame({"time": time, "FrL": signals[0], "FrR": signals[1], "OcR": signals[2]})

# %%
df.to_csv("all.csv", index=False)
